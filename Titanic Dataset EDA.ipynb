# %% [markdown]
# # ~~~~~~~~~~~~~~~~~~~ Titanic Dataset EDA ~~~~~~~~~~~~~~~~~~~

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("🔹 Dataset Info:")
df.info()
# Out:
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print("\n🔹 Missing Values:")
df.isnull().sum()
# Out:
# 🔹 Missing Values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# C:\Users\RAGHAV VYAS\AppData\Local\Temp\ipykernel_11736\1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.dropna(subset=['Embarked'], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# Survival Counts

plt.figure(figsize=(6, 4))
sns.countplot(data=titanic_df, x='Survived', palette='Set1')
plt.title('Survival Count')
plt.xticks([0, 1], ['Did Not Survive', 'Survived'])
plt.show()
# Out:
# C:\Users\RAGHAV VYAS\AppData\Local\Temp\ipykernel_11736\4045027001.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic_df, x='Survived', palette='Set1')

# %%
# Survival by Gender

plt.figure(figsize=(6, 4))
sns.countplot(data=titanic_df, x='Sex', hue='Survived', palette='Set2')
plt.title('Survival Count by Gender')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
# Survival by Class

plt.figure(figsize=(6, 4))
sns.countplot(data=titanic_df, x='Pclass', hue='Survived', palette='Set3')
plt.title('Survival Count by Class')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# %%
# Age Distribution by Survival

plt.figure(figsize=(8, 5))
sns.histplot(data=titanic_df, x='Age', hue='Survived', multiple='stack', bins=30, palette='viridis')
plt.title('Age Distribution by Survival')
plt.show()

# %%
# Age Boxplot by Survival

plt.figure(figsize=(6, 4))
sns.boxplot(data=titanic_df, x='Survived', y='Age', palette='Set3')
plt.title('Age Distribution by Survival')
plt.xticks([0, 1], ['Did Not Survive', 'Survived'])
plt.show()
# Out:
# C:\Users\RAGHAV VYAS\AppData\Local\Temp\ipykernel_11736\1631528770.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=titanic_df, x='Survived', y='Age', palette='Set3')

# %%
# Survival Rate by Gender and Class

grouped = df.groupby(['Sex', 'Pclass'])['Survived'].mean().unstack()
print("\n🔹 Survival Rate by Gender and Class:")
print(grouped)
# Out:
# 🔹 Survival Rate by Gender and Class:
# Pclass         1         2         3
# Sex
# female  0.967391  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
grouped.plot(kind='bar', figsize=(8, 5), colormap='Set1')
plt.title('Survival Rate by Gender and Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=0)
plt.show()

# %%
# Correlation Heatmap

plt.figure(figsize=(8, 6))
sns.heatmap(titanic_df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # OBSERVATION:

# %% [markdown]
# ~ Survival rate overall was 38.4% (342 out of 891 passengers).
#
# ~ Females had a survival rate of 74.2%, while males had only 18.9%.
#
# ~ 1st class passengers had a survival rate of 62.9%, compared to 24.2% in 3rd class.
#
# ~ Median age of passengers was 28.0 years, with survivors tending to be slightly younger.
#
# ~ Correlation analysis showed Fare (0.26) and Pclass (−0.34) had the strongest links with survival.
